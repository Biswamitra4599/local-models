# %% [markdown]
# <a href="https://colab.research.google.com/github/Biswamitra4599/local-models/blob/main/Copy_of_Ghibli_Diffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U diffusers

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/nitrosocke/Ghibli-Diffusion
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/nitrosocke/Ghibli-Diffusion)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
pip install -U diffusers transformers accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 95.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.3/394.3 kB 40.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.16.1
#     Uninstalling transformers-5.16.1:
#       Successfully uninstalled transformers-5.16.1
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.14.0
#     Uninstalling accelerate-1.14.0:
#       Successfully uninstalled accelerate-1.14.0
# ...

# %%
import torch
from diffusers import DiffusionPipeline

# switch to "mps" for apple devices
pipe = DiffusionPipeline.from_pretrained("nitrosocke/Ghibli-Diffusion", dtype=torch.bfloat16, device_map="cuda")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
